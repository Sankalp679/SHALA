# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# **Load the Data**

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# **Prepare Data**

# %%
num_classes=10
image_height=28
image_width=28
image_channels=1

# %%
# Shape the data using channels_last ordering
# num_samples*num_rows*num_columns*num_channels
x_train=x_train.reshape((x_train.shape[0],image_height,image_width,image_channels))
x_test=x_test.reshape((x_test.shape[0],image_height,image_width,image_channels))
x_test.shape
# Out:
# (10000, 28, 28, 1)

# %%
# scaling data in the range of [0.0,1.0]
x_train, x_test = x_train.astype("float64") / 255.0, x_test.astype("float64")/ 255.0

# %%
# Pad the data to 32x32 to use in Lenet network
x_train=np.pad(x_train,((0,0),(2,2),(2,2),(0,0)),mode='constant')
x_test=np.pad(x_test,((0,0),(2,2),(2,2),(0,0)),mode='constant')

# %%
# Display data_dimensions
print("x_train shape :",x_train.shape)
print("x_test shape :",x_test.shape)
print("y_train shape :",y_train.shape)
print("y_test shape :",y_test.shape)
# Out:
# x_train shape : (60000, 32, 32, 1)
# x_test shape : (10000, 32, 32, 1)
# y_train shape : (60000,)
# y_test shape : (10000,)

# %%
# parameters for training data set
num_classes=10
image_height=32
image_width=32
image_channels=1

# %%
# import necessary packages
from tensorflow.keras import backend
from tensorflow.keras import layers
from tensorflow.keras import models

# define model as a class
class LeNet:
  # INPUT => CONV => TANH => AVG-POOL => CONV => TANH => AVG-POOL => FC => TANH => FC => TANH => FC => SOFTMAX
  @staticmethod
  def init(num_classes,image_height,image_width,image_channels,weightsPath=None):
    # if we are using channel first then update the shape
    if backend.image_data_format()=='channels_first':
      inputShape=(image_channels,image_height,image_width)
    else:
      inputShape=(image_height,image_width,image_channels)

    # initalize the model
    model=models.Sequential()

    # Define first set of CONV => ACTIVATION => POOL layers
    model.add(layers.Conv2D(filters=6,kernel_size=(5,5),strides=(1,1),padding='valid',activation=tf.nn.tanh,input_shape=inputShape))
    model.add(layers.AveragePooling2D(pool_size=(2,2),strides=(2,2)))

    # Define second set of CONV => ACTIVATION => POOL layers
    model.add(layers.Conv2D(filters=6,kernel_size=(5,5),strides=(1,1),padding='valid',activation=tf.nn.tanh))
    model.add(layers.AveragePooling2D(pool_size=(2,2),strides=(2,2)))

    # Flatten the convolution volume to fully connected layers
    model.add(layers.Flatten())

    # Define the first FC => ACTIVATION layers
    model.add(layers.Dense(units=120,activation=tf.nn.tanh))

    # Define the second FC => ACTIVATION layers
    model.add(layers.Dense(units=84,activation=tf.nn.tanh))

    # lastly define the softmax classifier
    model.add(layers.Dense(units=num_classes,activation=tf.nn.softmax))

    # if weights path is supplied (indicating that model was pre-trained), then load the weights
    if weightsPath is not None :
      model.load_weights(weightsPath)
    
    # return the constructed network architecture
    return model

# %% [markdown]
# **Compile Model**

# %%
# initialize the model
model=LeNet.init(num_classes=num_classes,image_height=image_height,image_width=image_width,image_channels=image_channels,weightsPath=None)

# compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=.01),        #Stochiostic Gradient Descent
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 6)         906
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 6)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 150)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               18120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 30,196
# Trainable params: 30,196
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define callback function for training termination criteria
# accuracy_cutoff=.99

class myCallback(tf.keras.callbacks.Callback):
      def on_epoch_end(self, epoch, logs=None):
        if(logs.get('accuracy')>0.99):
          print("\nReached 99% accuracy so cancelling training!")
          self.model.stop_training = True

# initialize training configuration
batch_size=128
epochs=100

# run training
history = model.fit(x=x_train, y=y_train, validation_data=(x_test,y_test), epochs=epochs, batch_size=batch_size, callbacks=[myCallback()], verbose=1)
# Out:
# Epoch 1/100
# 469/469 [==============================] - 3s 7ms/step - loss: 1.2180 - accuracy: 0.6967 - val_loss: 0.6214 - val_accuracy: 0.8553
# Epoch 2/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5162 - accuracy: 0.8691 - val_loss: 0.4241 - val_accuracy: 0.8921
# Epoch 3/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3964 - accuracy: 0.8923 - val_loss: 0.3508 - val_accuracy: 0.9057
# Epoch 4/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3403 - accuracy: 0.9042 - val_loss: 0.3093 - val_accuracy: 0.9143
# Epoch 5/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3037 - accuracy: 0.9136 - val_loss: 0.2797 - val_accuracy: 0.9208
# Epoch 6/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2767 - accuracy: 0.9199 - val_loss: 0.2549 - val_accuracy: 0.9268
# Epoch 7/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2548 - accuracy: 0.9257 - val_loss: 0.2361 - val_accuracy: 0.9313
# Epoch 8/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2363 - accuracy: 0.9311 - val_loss: 0.2187 - val_accuracy: 0.9367
# Epoch 9/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2203 - accuracy: 0.9358 - val_loss: 0.2044 - val_accuracy: 0.9419
# Epoch 10/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2064 - accuracy: 0.9399 - val_loss: 0.1919 - val_accuracy: 0.9442
# Epoch 11/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1938 - accuracy: 0.9437 - val_loss: 0.1804 - val_accuracy: 0.9480
# Epoch 12/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1826 - accuracy: 0.9472 - val_loss: 0.1706 - val_accuracy: 0.9506
# Epoch 13/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1725 - accuracy: 0.9496 - val_loss: 0.1614 - val_accuracy: 0.9528
# Epoch 14/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1632 - accuracy: 0.9524 - val_loss: 0.1530 - val_accuracy: 0.9562
# Epoch 15/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1549 - accuracy: 0.9547 - val_loss: 0.1452 - val_accuracy: 0.9592
# Epoch 16/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1473 - accuracy: 0.9576 - val_loss: 0.1384 - val_accuracy: 0.9616
# Epoch 17/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1404 - accuracy: 0.9592 - val_loss: 0.1328 - val_accuracy: 0.9625
# Epoch 18/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1343 - accuracy: 0.9609 - val_loss: 0.1269 - val_accuracy: 0.9653
# Epoch 19/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1286 - accuracy: 0.9629 - val_loss: 0.1214 - val_accuracy: 0.9660
# Epoch 20/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1235 - accuracy: 0.9643 - val_loss: 0.1161 - val_accuracy: 0.9674
# Epoch 21/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1190 - accuracy: 0.9655 - val_loss: 0.1123 - val_accuracy: 0.9681
# Epoch 22/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1147 - accuracy: 0.9669 - val_loss: 0.1088 - val_accuracy: 0.9702
# Epoch 23/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1108 - accuracy: 0.9681 - val_loss: 0.1051 - val_accuracy: 0.9703
# Epoch 24/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1073 - accuracy: 0.9694 - val_loss: 0.1020 - val_accuracy: 0.9717
# Epoch 25/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1041 - accuracy: 0.9700 - val_loss: 0.0990 - val_accuracy: 0.9721
# Epoch 26/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1010 - accuracy: 0.9707 - val_loss: 0.0962 - val_accuracy: 0.9722
# Epoch 27/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0982 - accuracy: 0.9713 - val_loss: 0.0939 - val_accuracy: 0.9739
# Epoch 28/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0956 - accuracy: 0.9725 - val_loss: 0.0918 - val_accuracy: 0.9736
# Epoch 29/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0932 - accuracy: 0.9728 - val_loss: 0.0886 - val_accuracy: 0.9743
# Epoch 30/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0908 - accuracy: 0.9736 - val_loss: 0.0869 - val_accuracy: 0.9749
# Epoch 31/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0887 - accuracy: 0.9739 - val_loss: 0.0855 - val_accuracy: 0.9745
# Epoch 32/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0868 - accuracy: 0.9745 - val_loss: 0.0829 - val_accuracy: 0.9752
# Epoch 33/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0849 - accuracy: 0.9750 - val_loss: 0.0813 - val_accuracy: 0.9760
# Epoch 34/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0830 - accuracy: 0.9756 - val_loss: 0.0802 - val_accuracy: 0.9753
# Epoch 35/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0814 - accuracy: 0.9759 - val_loss: 0.0783 - val_accuracy: 0.9768
# Epoch 36/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0798 - accuracy: 0.9766 - val_loss: 0.0767 - val_accuracy: 0.9769
# Epoch 37/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0782 - accuracy: 0.9769 - val_loss: 0.0754 - val_accuracy: 0.9772
# Epoch 38/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0769 - accuracy: 0.9776 - val_loss: 0.0743 - val_accuracy: 0.9775
# Epoch 39/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0754 - accuracy: 0.9776 - val_loss: 0.0739 - val_accuracy: 0.9772
# Epoch 40/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0742 - accuracy: 0.9781 - val_loss: 0.0724 - val_accuracy: 0.9774
# Epoch 41/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0730 - accuracy: 0.9786 - val_loss: 0.0709 - val_accuracy: 0.9776
# Epoch 42/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0715 - accuracy: 0.9790 - val_loss: 0.0721 - val_accuracy: 0.9777
# Epoch 43/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0704 - accuracy: 0.9795 - val_loss: 0.0686 - val_accuracy: 0.9787
# Epoch 44/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0694 - accuracy: 0.9798 - val_loss: 0.0682 - val_accuracy: 0.9789
# Epoch 45/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0684 - accuracy: 0.9801 - val_loss: 0.0673 - val_accuracy: 0.9787
# Epoch 46/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0673 - accuracy: 0.9805 - val_loss: 0.0662 - val_accuracy: 0.9789
# Epoch 47/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0664 - accuracy: 0.9807 - val_loss: 0.0656 - val_accuracy: 0.9801
# Epoch 48/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0654 - accuracy: 0.9811 - val_loss: 0.0651 - val_accuracy: 0.9797
# Epoch 49/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0644 - accuracy: 0.9814 - val_loss: 0.0641 - val_accuracy: 0.9795
# Epoch 50/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0637 - accuracy: 0.9815 - val_loss: 0.0638 - val_accuracy: 0.9798
# Epoch 51/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0627 - accuracy: 0.9818 - val_loss: 0.0629 - val_accuracy: 0.9801
# Epoch 52/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0619 - accuracy: 0.9820 - val_loss: 0.0622 - val_accuracy: 0.9796
# Epoch 53/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0611 - accuracy: 0.9823 - val_loss: 0.0615 - val_accuracy: 0.9806
# Epoch 54/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0603 - accuracy: 0.9825 - val_loss: 0.0607 - val_accuracy: 0.9803
# Epoch 55/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0596 - accuracy: 0.9825 - val_loss: 0.0604 - val_accuracy: 0.9802
# Epoch 56/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0589 - accuracy: 0.9830 - val_loss: 0.0590 - val_accuracy: 0.9811
# Epoch 57/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0582 - accuracy: 0.9830 - val_loss: 0.0593 - val_accuracy: 0.9808
# Epoch 58/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0575 - accuracy: 0.9831 - val_loss: 0.0584 - val_accuracy: 0.9810
# Epoch 59/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0567 - accuracy: 0.9835 - val_loss: 0.0588 - val_accuracy: 0.9810
# Epoch 60/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0563 - accuracy: 0.9838 - val_loss: 0.0571 - val_accuracy: 0.9813
# Epoch 61/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0555 - accuracy: 0.9839 - val_loss: 0.0570 - val_accuracy: 0.9811
# Epoch 62/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0550 - accuracy: 0.9838 - val_loss: 0.0566 - val_accuracy: 0.9815
# Epoch 63/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0542 - accuracy: 0.9842 - val_loss: 0.0564 - val_accuracy: 0.9819
# Epoch 64/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0537 - accuracy: 0.9842 - val_loss: 0.0557 - val_accuracy: 0.9817
# Epoch 65/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0531 - accuracy: 0.9847 - val_loss: 0.0549 - val_accuracy: 0.9821
# Epoch 66/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0526 - accuracy: 0.9847 - val_loss: 0.0556 - val_accuracy: 0.9812
# Epoch 67/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0521 - accuracy: 0.9847 - val_loss: 0.0544 - val_accuracy: 0.9823
# Epoch 68/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0515 - accuracy: 0.9850 - val_loss: 0.0540 - val_accuracy: 0.9820
# Epoch 69/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0509 - accuracy: 0.9850 - val_loss: 0.0533 - val_accuracy: 0.9827
# Epoch 70/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0504 - accuracy: 0.9853 - val_loss: 0.0535 - val_accuracy: 0.9824
# Epoch 71/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0500 - accuracy: 0.9853 - val_loss: 0.0529 - val_accuracy: 0.9830
# Epoch 72/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0495 - accuracy: 0.9854 - val_loss: 0.0522 - val_accuracy: 0.9833
# Epoch 73/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0491 - accuracy: 0.9855 - val_loss: 0.0526 - val_accuracy: 0.9826
# Epoch 74/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0486 - accuracy: 0.9859 - val_loss: 0.0518 - val_accuracy: 0.9827
# Epoch 75/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0482 - accuracy: 0.9858 - val_loss: 0.0514 - val_accuracy: 0.9835
# Epoch 76/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0476 - accuracy: 0.9862 - val_loss: 0.0510 - val_accuracy: 0.9835
# Epoch 77/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0473 - accuracy: 0.9862 - val_loss: 0.0507 - val_accuracy: 0.9832
# Epoch 78/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0468 - accuracy: 0.9861 - val_loss: 0.0511 - val_accuracy: 0.9834
# Epoch 79/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0463 - accuracy: 0.9865 - val_loss: 0.0512 - val_accuracy: 0.9830
# Epoch 80/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0460 - accuracy: 0.9866 - val_loss: 0.0495 - val_accuracy: 0.9842
# Epoch 81/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0456 - accuracy: 0.9867 - val_loss: 0.0497 - val_accuracy: 0.9837
# Epoch 82/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0451 - accuracy: 0.9866 - val_loss: 0.0495 - val_accuracy: 0.9846
# Epoch 83/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0449 - accuracy: 0.9867 - val_loss: 0.0500 - val_accuracy: 0.9838
# Epoch 84/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0443 - accuracy: 0.9872 - val_loss: 0.0488 - val_accuracy: 0.9843
# Epoch 85/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0439 - accuracy: 0.9872 - val_loss: 0.0497 - val_accuracy: 0.9834
# Epoch 86/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0437 - accuracy: 0.9871 - val_loss: 0.0483 - val_accuracy: 0.9844
# Epoch 87/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0433 - accuracy: 0.9875 - val_loss: 0.0496 - val_accuracy: 0.9842
# Epoch 88/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0429 - accuracy: 0.9874 - val_loss: 0.0476 - val_accuracy: 0.9851
# Epoch 89/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0426 - accuracy: 0.9875 - val_loss: 0.0480 - val_accuracy: 0.9844
# Epoch 90/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0423 - accuracy: 0.9878 - val_loss: 0.0478 - val_accuracy: 0.9845
# Epoch 91/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0420 - accuracy: 0.9877 - val_loss: 0.0470 - val_accuracy: 0.9851
# Epoch 92/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0415 - accuracy: 0.9880 - val_loss: 0.0471 - val_accuracy: 0.9848
# Epoch 93/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0411 - accuracy: 0.9881 - val_loss: 0.0468 - val_accuracy: 0.9848
# Epoch 94/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0408 - accuracy: 0.9885 - val_loss: 0.0462 - val_accuracy: 0.9850
# Epoch 95/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0405 - accuracy: 0.9882 - val_loss: 0.0470 - val_accuracy: 0.9851
# Epoch 96/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0402 - accuracy: 0.9884 - val_loss: 0.0459 - val_accuracy: 0.9849
# Epoch 97/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0399 - accuracy: 0.9884 - val_loss: 0.0461 - val_accuracy: 0.9851
# Epoch 98/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0397 - accuracy: 0.9885 - val_loss: 0.0457 - val_accuracy: 0.9857
# Epoch 99/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0393 - accuracy: 0.9888 - val_loss: 0.0453 - val_accuracy: 0.9855
# Epoch 100/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0391 - accuracy: 0.9887 - val_loss: 0.0452 - val_accuracy: 0.9853

# %% [markdown]
# **Evaluating Training Performance**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# show accuracy on testing set
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=1, batch_size=batch_size)
print("test accuracy : {:.2f}%".format(test_acc*100))
# Out:
# 79/79 [==============================] - 0s 3ms/step - loss: 0.0452 - accuracy: 0.9853
# test accuracy : 98.53%

# %%
model.save_weights("/usr/LeNet",overwrite=True)

# %% [markdown]
# **Evaluate Pre-trained Model**

# %%
# init model and load the model weights
# initialize the model
model=LeNet.init(num_classes=num_classes,image_height=image_height,image_width=image_width,image_channels=image_channels,weightsPath="/usr/LeNet")

# compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=.01),        #Stochiostic Gradient Descent
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 6)         906
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 5, 5, 6)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 150)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               18120
# _________________________________________________________________
# dense_4 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                850
# =================================================================
# Total params: 30,196
# Trainable params: 30,196
# Non-trainable params: 0
# _________________________________________________________________

# %%
# show accuracy on testing set
batch_size=128
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=1, batch_size=batch_size)
print("test accuracy : {:.2f}%".format(test_acc*100))
# Out:
# 79/79 [==============================] - 0s 3ms/step - loss: 0.0452 - accuracy: 0.9853
# test accuracy : 98.53%

# %% [markdown]
# **Model Predictions**

# %%
# %matplotlib inline
import numpy as np
import cv2
import matplotlib.pyplot as plt

# set up matplotlib figure and size it to fit 3*4 pics
nrows= 3
ncolumns= 4
fig = plt.gcf()
fig.set_size_inches(ncolumns*4,nrows*4)

# Randomly select few testing digits
num_predictions=12
test_indices=np.random.choice(np.arange(0,len(y_test)),size=(num_predictions,))
test_images=np.stack([x_test[i] for i in test_indices])     #not understood how it is printed based on shape
test_labels=np.stack([y_test[i] for i in test_indices])     #and not understood how it is stacked

# # compute predictions
predictions=model.predict(test_images)

for i in range(num_predictions):
  # select the most probable class
  prediction=np.argmax(predictions[i])

  # rescale the test image
  image=(test_images[i]*255).astype("uint8")
  
  # resize the image from 28x28 to 96x96 so that we can see it better
  image=cv2.resize(image,(96,96),interpolation=cv2.INTER_CUBIC)      # INTER_CUBIC – a bicubic interpolation over 4×4 pixel neighborhood 
                                                                     #how 32*32*1 is converted to 96*96  

  # convert gray scale image to RGB color
  image=cv2.merge([image]*3)

  # select prediction text color 
  if prediction == test_labels[i]:
    rgb_color = (0, 255, 0)    #green for correct predictions
  else:
    rgb_color = (255, 0, 0)    #red for wrong predictions
  
  # show the image and prediction
  cv2.putText(image, str(prediction), (0,18), cv2.FONT_HERSHEY_SIMPLEX, 0.75, rgb_color, 1)

  # set up subplot, subplot indices start at 1
  sp = plt.subplot(nrows, ncolumns, i+1, title="label: %s" %test_labels[i])
  sp.axis("Off")  #don't show axes(or gridlines)
  plt.imshow(image)                                                 #not understood difference between plt.imshow() and plt.show()

# show figure matrix
plt.show()
